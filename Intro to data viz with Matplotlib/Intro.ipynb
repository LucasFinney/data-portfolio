# %% [markdown]
# # Preliminary

# %%
# Importing the course packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importing the course datasets 
climate_change = pd.read_csv('../datasets/climate_change.csv', parse_dates=["date"], index_col="date")
medals = pd.read_csv('../datasets/medals_by_country_2016.csv', index_col=0)
summer_2016 = pd.read_csv('../datasets/summer2016.csv')
austin_weather = pd.read_csv("../datasets/austin_weather.csv", index_col="DATE")
weather = pd.read_csv("../datasets/seattle_weather.csv", index_col="DATE")

# Some pre-processing on the weather datasets, including adding a month column
seattle_weather = weather[weather["STATION"] == "USW00094290"] 
month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"] 
seattle_weather.loc[:,"MONTH"] = month 
austin_weather.loc[:,"MONTH"] = month
# Out:
# C:\Users\lucfi\AppData\Local\Temp\ipykernel_53000\3068007146.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_weather.loc[:,"MONTH"] = month

# %% [markdown]
# # Data Viz
#
# ## Introducing the pyplot interface

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# plt.subplots() creates two objects: a figure and an axis
# - Figure: container that holds the visuals
# - Axis: holds data ("canvas")

# %%
fig, ax = plt.subplots()
# Adding data: ex. month and monthly avg temp
ax.plot(seattle_weather['MONTH'], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather['MONTH'], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [raw]
# Plotting commands - Methods of the axes object. Ex. ax.plot()
# plt.show() adds a line to the plot
# Note: Can add multiple lines to the plot by using multiple ax.plot commands

# %% [markdown]
# # Customizing Plots

# %% [raw]
# Customizing appearance:
# - Continuous to discrete -> Add markers
# ax.plot(marker="o") -> use circles as markers, use "v" for diamond/triangles
# - use arg linestyle="--" to change line to dashed
# - use arg linestyle="None" to remove line
# - use arg color = "r" to change color (to red, for example)
#
# Adding axis labels:
# - use ax.set_xlabel or ax.set_ylabel *ON THE AXES OBJECT*
# - use ax.legend(["plot 1","plot 2"]) to set the legend, using labels in order of the ax.plot commands

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather['MONTH'], seattle_weather["MLY-TAVG-NORMAL"], marker="o",linestyle="--", color="r")
ax.plot(austin_weather['MONTH'], austin_weather["MLY-TAVG-NORMAL"],marker="v",linestyle="--",color="b")
ax.set_xlabel("Time (months)")
ax.set_ylabel("Temperature (Farenheit)")
ax.set_title("Monthly Average Temperature")
ax.legend(["Seattle","Austin"])
plt.show()

# %% [markdown]
# # Small Multiples

# %% [raw]
# - Trying to plot too much data will make a mess. Use "small multiples" to avoid. Multiple small plots with similar data (subplots)
# - Caling plt.subplots() with no inputs will create one subplot
# - pass number of rows and number of columns (ie. plt.subplots(m,n)) to make an m x n grid of subplots
# - Variable ax becomes an array of axes objects
# - Index into the object to specify what goes where
# - If one dimensional, only specify 1 index (ie. ax[0] rather than ax[0,0])
# - Use sharey=True argument in the Subplots function to make sure everything has the same y axis range

# %%
fig, ax = plt.subplots(2,2,sharey=True)
ax[0,0].plot(seattle_weather['MONTH'], seattle_weather["MLY-TAVG-NORMAL"], marker="o",linestyle="--", color="r")
ax[0,1].plot(seattle_weather['MONTH'], seattle_weather["MLY-PRCP-NORMAL"], marker="o",linestyle="--", color="r")
ax[1,0].plot(austin_weather['MONTH'], austin_weather["MLY-TAVG-NORMAL"],marker="v",linestyle="--",color="b")
ax[1,1].plot(austin_weather['MONTH'], austin_weather["MLY-PRCP-NORMAL"],marker="v",linestyle="--",color="b")
ax[1,0].set_xlabel("Time (months)")
ax[0,0].set_ylabel("Temperature (Farenheit)")
ax[0,0].set_title("Monthly Average Temperature")
ax[0,0].legend(["Seattle"])
ax[1,0].legend(["Austin"])
plt.show()
